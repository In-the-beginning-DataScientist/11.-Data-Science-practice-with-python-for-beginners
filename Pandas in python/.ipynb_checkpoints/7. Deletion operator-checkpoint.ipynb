# %%
import numpy as np
import pandas as pd

# %%
datasetDF = pd.read_csv("Output of dupliactes removed file.csv")

# %%
datasetDF
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
# delete Esalary and EsalaryYearly
datasetDF.drop(["Esalary","EsalaryYearly"], axis=1)
# Out:
#    Eid    Ename  updatedMonthlySalary  updatedSalaryYearly       Dept  \
# 0    1  Aravind                1100.0              13200.0         HR
# 1    2  Sharada                2100.0              25200.0     Design
# 2    3  Rachael                2100.0              25200.0  Operation
# 3    4     Dave                2100.0              25200.0        PMG
# 4    5    Rhema                9878.0             118536.0   Delivery
# 5    6  Rachael                9999.0             119988.0    Testing
#
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 4         Chennai
# 5         Kurnool

# %%
datasetDF
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
# the above drop/delete operation is not committed, means not permanemntly deleted
# this is only to check for drop details

# %%
# delete a column
# to drop completely even into DF then use inplace=True
datasetDF.drop(["Esalary","EsalaryYearly"], axis=1 , inplace=True)

# %%
datasetDF
# Out:
#    Eid    Ename  updatedMonthlySalary  updatedSalaryYearly       Dept  \
# 0    1  Aravind                1100.0              13200.0         HR
# 1    2  Sharada                2100.0              25200.0     Design
# 2    3  Rachael                2100.0              25200.0  Operation
# 3    4     Dave                2100.0              25200.0        PMG
# 4    5    Rhema                9878.0             118536.0   Delivery
# 5    6  Rachael                9999.0             119988.0    Testing
#
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 4         Chennai
# 5         Kurnool

# %%
# Delete a row
# in both the cases, drop can take only indexes.

# %%
datasetDF.drop([5], axis=0)
# Out:
#    Eid    Ename  updatedMonthlySalary  updatedSalaryYearly       Dept  \
# 0    1  Aravind                1100.0              13200.0         HR
# 1    2  Sharada                2100.0              25200.0     Design
# 2    3  Rachael                2100.0              25200.0  Operation
# 3    4     Dave                2100.0              25200.0        PMG
# 4    5    Rhema                9878.0             118536.0   Delivery
#
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 4         Chennai

# %%
# here based on row index its dropped, ofcourse not committed
datasetDF
# Out:
#    Eid    Ename  updatedMonthlySalary  updatedSalaryYearly       Dept  \
# 0    1  Aravind                1100.0              13200.0         HR
# 1    2  Sharada                2100.0              25200.0     Design
# 2    3  Rachael                2100.0              25200.0  Operation
# 3    4     Dave                2100.0              25200.0        PMG
# 4    5    Rhema                9878.0             118536.0   Delivery
# 5    6  Rachael                9999.0             119988.0    Testing
#
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 4         Chennai
# 5         Kurnool

# %%
# How dynamically trace the indexes and to drop the same
datasetDF[datasetDF.Eid==5].index
# Out:
# Int64Index([4], dtype='int64')

# %%
datasetDF.drop(datasetDF[datasetDF.Eid==5].index , axis=0)
# Out:
#    Eid    Ename  updatedMonthlySalary  updatedSalaryYearly       Dept  \
# 0    1  Aravind                1100.0              13200.0         HR
# 1    2  Sharada                2100.0              25200.0     Design
# 2    3  Rachael                2100.0              25200.0  Operation
# 3    4     Dave                2100.0              25200.0        PMG
# 5    6  Rachael                9999.0             119988.0    Testing
#
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 5         Kurnool

# %%
# truncate thre yable data
datasetDF.truncate(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8837efc1e42e> in <module>
#       1 # truncate thre yable data
# ----> 2 datasetDF.truncate(inplace=True)
#
# TypeError: truncate() got an unexpected keyword argument 'inplace'
