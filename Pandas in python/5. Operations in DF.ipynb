# %%
# OPERATION-1: Relational, logical and comparison operation

# %%
import numpy as np
import pandas as pd

# %%
datasetExample = pd.read_csv("Finaloutput of empWithHeaderDF.csv")

# %%
datasetExample
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept
# 0              13200.0         HR
# 1              25200.0     Design
# 2              25200.0  Operation
# 3              25200.0        PMG
# 4             118536.0   Delivery
# 5             119988.0    Testing

# %%
# extract record of emp. whose salary is greater than 5000
datasetExample.Esalary>5000
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# Name: Esalary, dtype: bool

# %%
datasetExample[datasetExample.Esalary>5000]
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly      Dept
# 4             118536.0  Delivery
# 5             119988.0   Testing

# %%
# extract record of Ename and Dept of emp. whose salary is greater than 5000
datasetExample.iloc[0:, [1,6]][datasetExample.Esalary>5000]
# Out:
#      Ename      Dept
# 4    Rhema  Delivery
# 5  Rachael   Testing

# %%
datasetExample[datasetExample.Esalary>5000].iloc[:, [1,6]]
# Out:
#      Ename      Dept
# 4    Rhema  Delivery
# 5  Rachael   Testing

# %%
# extract the data whose salary is > 8000 and belongs to Delivery team
datasetExample
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept
# 0              13200.0         HR
# 1              25200.0     Design
# 2              25200.0  Operation
# 3              25200.0        PMG
# 4             118536.0   Delivery
# 5             119988.0    Testing

# %%
datasetExample[(datasetExample.Esalary>8000) & (datasetExample.Dept=="Delivery")]
# Out:
#    Eid  Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 4    5  Rhema     9878         118536                9878.0
#
#    updatedSalaryYearly      Dept
# 4             118536.0  Delivery

# %%
# tuple is compulsory when use logical contions for biwise operator

# %%
# list the names of the employees whose salary is >1900 and belongs to operation team
datasetExample
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept
# 0              13200.0         HR
# 1              25200.0     Design
# 2              25200.0  Operation
# 3              25200.0        PMG
# 4             118536.0   Delivery
# 5             119988.0    Testing

# %%
datasetExample.iloc[0:,1][(datasetExample.Esalary>1990) & (datasetExample.Dept=="Operation")]
# Out:
# 2    Rachael
# Name: Ename, dtype: object

# %%
datasetExample[(datasetExample.Esalary>1990) & (datasetExample.Dept=="Operation")].Ename
# Out:
# 2    Rachael
# Name: Ename, dtype: object

# %%
datasetExample[(datasetExample.Esalary>1990) & (datasetExample.Dept=="Operation")].iloc[0:,1]
# Out:
# 2    Rachael
# Name: Ename, dtype: object

# %%
datasetExample[(datasetExample.Esalary>1990) & (datasetExample.Dept=="Operation")].iloc[0:,1].to_frame()
# Out:
#      Ename
# 2  Rachael

# %%
# the functions are worked well with . operator..
# but if there is a space in the columns names like yearly salary instead of yearlysalary,
# there will be a problem

# %%
# check with space once
datasetExample["area of working"] = [" Bangalore","Hyderabad","Bangalore","Hyderabad","Chennai","Kurnool"]

# %%
datasetExample
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
datasetExample.area of working
# Out:
#   File "<ipython-input-25-673b5d2ebf67>", line 1
#     datasetExample.area of working
#                         ^
# SyntaxError: invalid syntax

# %%
#.(dot) operator will not work if there is a space in the name of the column

# %%
# instead of . , we can use [""]
datasetExample["area of working"]
# Out:
# 0     Bangalore
# 1     Hyderabad
# 2     Bangalore
# 3     Hyderabad
# 4       Chennai
# 5       Kurnool
# Name: area of working, dtype: object

# %%
#everything is same except . operator

# %%
datasetExample["area of working"].to_frame()
# Out:
#   area of working
# 0       Bangalore
# 1       Hyderabad
# 2       Bangalore
# 3       Hyderabad
# 4         Chennai
# 5         Kurnool

# %%
datasetExample[datasetExample.area of working ==" Hyderabad"]
# Out:
#   File "<ipython-input-30-dd18b261b0e4>", line 1
#     datasetExample[datasetExample.area of working ==" Hyderabad"]
#                                        ^
# SyntaxError: invalid syntax

# %%
# .operator will throw an error when there is a space in the name of the column

# %%
datasetExample[datasetExample["area of working"]=="Hyderabad"]
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 1    2  Sharada     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
#
#    updatedSalaryYearly    Dept area of working
# 1              25200.0  Design       Hyderabad
# 3              25200.0     PMG       Hyderabad

# %%
datasetExample[datasetExample["area of working"]=="Hyderabad"]
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 1    2  Sharada     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
#
#    updatedSalaryYearly    Dept area of working
# 1              25200.0  Design       Hyderabad
# 3              25200.0     PMG       Hyderabad

# %% [markdown]
# # Operation-2: Dealing of duplicate rows

# %%
# duplicate records
# full records in the row should be same , then only it will become dupliactes and will be removed
datasetExample
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
datasetExample.drop_duplicates() # without commit in the real data frame
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
# here there are no dupliactes

# %%
# the above code is only to check for duplicates.. it will not commit to remove

# %%
datasetExample.drop_duplicates( inplace=True)  # inplace is an commit operation in database
# this will commit to change the records in DF

# %%
datasetExample # this is after removal of duplicates
# Out:
#    Eid    Ename  Esalary  EsalaryYearly  updatedMonthlySalary  \
# 0    1  Aravind     1000          12000                1100.0
# 1    2  Sharada     2000          24000                2100.0
# 2    3  Rachael     2000          24000                2100.0
# 3    4     Dave     2000          24000                2100.0
# 4    5    Rhema     9878         118536                9878.0
# 5    6  Rachael     9999         119988                9999.0
#
#    updatedSalaryYearly       Dept area of working
# 0              13200.0         HR       Bangalore
# 1              25200.0     Design       Hyderabad
# 2              25200.0  Operation       Bangalore
# 3              25200.0        PMG       Hyderabad
# 4             118536.0   Delivery         Chennai
# 5             119988.0    Testing         Kurnool

# %%
# Whenever dupliactes get deleted, the the numbers of index will be affected..
# that is, that row row number as index number will be removed completely
# This index number affects the analysis..
# so to reset the index, we need to do thr reset index.
# next class we will see for reset index technic.

# %%
# when we say commiting the data to be removed...in python, obejects are stored in memory objects..
# so it will works on memory obects.
# right now its working on RAM..
# the moment close the jupyternotebook lab, it will be removed from the moemory objects.

# %%
datasetExample.to_csv("Output of dupliactes removed file.csv", index=False)
